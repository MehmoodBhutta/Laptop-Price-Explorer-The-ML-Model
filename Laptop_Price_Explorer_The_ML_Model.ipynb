# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_absolute_error
from sklearn.preprocessing import StandardScaler
from sklearn.decomposition import PCA
from sklearn.feature_selection import RFE
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor, GradientBoostingRegressor
from sklearn.svm import SVR
from sklearn.model_selection import cross_val_score
from sklearn.metrics import mean_squared_error
from sklearn.metrics import mean_absolute_error, r2_score
from sklearn.model_selection import GridSearchCV

# %% [markdown]
#  # loading dataset / cleaning

# %%
df = pd.read_csv('laptops.csv')

# %%
df.head()
# Out:
#   CompanyName        TypeOfLaptop     Inches  \
# 0         MSI     Business Laptop  17.040680
# 1       Chuwi  2 in 1 Convertible  16.542395
# 2          hp         WorkStation  17.295294
# 3         MSI  2 in 1 Convertible  11.526203
# 4   Microsoft              Gaming  12.649634
#
#                      ScreenResolution                   Cpu   Ram  \
# 0  IPS Panel Retina Display 2560x1600         Intel Core i7  12GB
# 1                             Full HD         Intel Core i5  12GB
# 2                             Full HD  Intel Xeon E3-1505M    8GB
# 3                                  2K         Intel Core i7  16GB
# 4                             Full HD         Intel Core i5   8GB
#
#            Memory                     Gpu       OpSys    Weight         Price
# 0       512GB SSD  Intel Iris Xe Graphics       Linux  2.064834  35844.099371
# 1  128GB PCIe SSD  Intel Iris Xe Graphics       No OS  4.060656  37019.059051
# 2         1TB HDD  Intel Iris Xe Graphics       Linux  2.901689  33329.360341
# 3  512GB NVMe SSD  Intel Iris Xe Graphics  Windows 10  2.914843  68631.102486
# 4       512GB SSD     AMD Radeon RX 5600M  Windows 10  4.341995  33842.479566

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 11 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   CompanyName       1000 non-null   object
#  1   TypeOfLaptop      1000 non-null   object
#  2   Inches            1000 non-null   float64
#  3   ScreenResolution  1000 non-null   object
#  4   Cpu               1000 non-null   object
#  5   Ram               1000 non-null   object
#  6   Memory            1000 non-null   object
#  7   Gpu               1000 non-null   object
#  8   OpSys             1000 non-null   object
#  9   Weight            1000 non-null   float64
#  10  Price             1000 non-null   float64
# dtypes: float64(3), object(8)
# memory usage: 86.1+ KB

# %%
df.shape
# Out:
# (1000, 11)

# %%
df.isna().sum()
# Out:
# CompanyName         0
# TypeOfLaptop        0
# Inches              0
# ScreenResolution    0
# Cpu                 0
# Ram                 0
# Memory              0
# Gpu                 0
# OpSys               0
# Weight              0
# Price               0
# dtype: int64

# %% [markdown]
# # Data Analysis (EDA)

# %%
df.describe()
# Out:
#             Inches       Weight          Price
# count  1000.000000  1000.000000    1000.000000
# mean     14.496646     3.469800   51602.255339
# std       2.066624     0.857112   13802.833231
# min      11.005842     2.000819   30060.275100
# 25%      12.677791     2.720228   40376.617670
# 50%      14.509298     3.477824   50683.971717
# 75%      16.313026     4.189891   61897.280126
# max      17.998786     4.994556  115137.368077

# %%
# 1. Type of Laptop
type_count = df['TypeOfLaptop'].value_counts().reset_index()
type_count.columns = ['TypeOfLaptop', 'Count']

fig = px.bar(type_count, x='TypeOfLaptop', y='Count', title='Distribution of Laptop Types', labels={'Count': 'Number of Laptops', 'TypeOfLaptop': 'Type of Laptop'})
fig.update_layout(xaxis=dict(tickangle=45))
fig.show()

# 2. Screen Resolution
resolution_count = df['ScreenResolution'].value_counts().reset_index()
resolution_count.columns = ['ScreenResolution', 'Count']

fig = px.bar(resolution_count, x='ScreenResolution', y='Count', title='Distribution of Screen Resolutions', labels={'Count': 'Number of Laptops', 'ScreenResolution': 'Screen Resolution'})
fig.update_layout(xaxis=dict(tickangle=45))
fig.show()

# 3. CPU
cpu_count = df['Cpu'].value_counts().reset_index()
cpu_count.columns = ['Cpu', 'Count']

fig = px.bar(cpu_count, x='Cpu', y='Count', title='Distribution of CPU Types', labels={'Count': 'Number of Laptops', 'Cpu': 'CPU Type'})
fig.update_layout(xaxis=dict(tickangle=45))
fig.show()

# 4. GPU
gpu_count = df['Gpu'].value_counts().reset_index()
gpu_count.columns = ['Gpu', 'Count']

fig = px.bar(gpu_count, x='Gpu', y='Count', title='Distribution of GPU Types', labels={'Count': 'Number of Laptops', 'Gpu': 'GPU Type'})
fig.update_layout(xaxis=dict(tickangle=45))
fig.show()

# 5. Operating System
os_count = df['OpSys'].value_counts().reset_index()
os_count.columns = ['OpSys', 'Count']

fig = px.bar(os_count, x='OpSys', y='Count', title='Distribution of Operating Systems', labels={'Count': 'Number of Laptops', 'OpSys': 'Operating System'})
fig.update_layout(xaxis=dict(tickangle=45))
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="c583dfc0-228f-4c03-abad-c8a3789e3913" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("c583dfc0-228f-4c03-abad-c8a3789e3913")) {                    Plotly.newPlot(                        "c583dfc0-228f-4c03-abad-c8a3789e3913",                        [{"alignmentgroup":"True","hovertemplate":"Type of Laptop=%{x}\u003cbr\u003eNumber of Laptops=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Business Laptop","WorkStation","Gaming","UltraBook","2 in 1 Convertible","NoteBook"],"xaxis":"x","y":[176,175,168,166,162,153],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"sc ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="b71647af-115a-418a-b4bf-7f561d76bf69" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("b71647af-115a-418a-b4bf-7f561d76bf69")) {                    Plotly.newPlot(                        "b71647af-115a-418a-b4bf-7f561d76bf69",                        [{"alignmentgroup":"True","hovertemplate":"Screen Resolution=%{x}\u003cbr\u003eNumber of Laptops=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["2K","4K","IPS Panel Full HD \u002f Touchscreen 1920x1080","Full HD","HD 1920x1080 ","IPS Panel Retina Display 2560x1600"],"xaxis":"x","y":[181,179,176,162,160,142],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="7413f2ee-aa82-4acf-80ba-1f9b871ae04d" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("7413f2ee-aa82-4acf-80ba-1f9b871ae04d")) {                    Plotly.newPlot(                        "7413f2ee-aa82-4acf-80ba-1f9b871ae04d",                        [{"alignmentgroup":"True","hovertemplate":"CPU Type=%{x}\u003cbr\u003eNumber of Laptops=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["Intel Xeon E3-1505M ","Intel Atom x5-Z8550","Intel Core i5","Intel Pentium Quad Core N4200","Intel Celeron Dual Core 3855U ","Intel Core i7","Intel Core i9","AMD Ryzen 5","AMD Ryzen 7","AMD A9-Series 9420"],"xaxis":"x","y":[114,111,105,101,98,96,95,94,94,92],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"}, ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="35de2471-adba-4dc7-bc9b-8ee8d49473aa" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("35de2471-adba-4dc7-bc9b-8ee8d49473aa")) {                    Plotly.newPlot(                        "35de2471-adba-4dc7-bc9b-8ee8d49473aa",                        [{"alignmentgroup":"True","hovertemplate":"GPU Type=%{x}\u003cbr\u003eNumber of Laptops=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["NVIDIA GeForce GTX 1650","AMD Radeon RX 5600M","Intel Iris Xe Graphics"],"xaxis":"x","y":[348,339,313],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="43b2136d-8e24-457d-883b-a00f9ccbb5ce" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("43b2136d-8e24-457d-883b-a00f9ccbb5ce")) {                    Plotly.newPlot(                        "43b2136d-8e24-457d-883b-a00f9ccbb5ce",                        [{"alignmentgroup":"True","hovertemplate":"Operating System=%{x}\u003cbr\u003eNumber of Laptops=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["No OS","macOS","Windows 10","Linux","Windows 11"],"xaxis":"x","y":[224,219,194,187,176],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{"type":"scattergeo","mark ...

# %%
# Company Distribution
company_distribution = df['CompanyName'].value_counts().reset_index()
company_distribution.columns = ['CompanyName', 'Count']

fig = px.bar(company_distribution, x='CompanyName', y='Count', title='Distribution of Laptops by Company', labels={'Count': 'Number of Laptops', 'CompanyName': 'Company'})
fig.update_layout(xaxis=dict(tickangle=45))
fig.show()


# Correlations Between Numerical Variables
# Scatter Plot Matrix
fig = px.scatter_matrix(df, dimensions=['Inches', 'Ram', 'Weight', 'Price'], title='Scatter Plot Matrix of Numerical Variables')
fig.show()

# Visualize the Distribution of Prices

# Price Distribution
fig = px.histogram(df, x='Price', title='Distribution of Laptop Prices', labels={'Price': 'Laptop Price'})
fig.show()

# Scatter Plot: Price vs. Weight
fig = px.scatter(df, x='Weight', y='Price', title='Scatter Plot: Weight vs. Price', labels={'Weight': 'Laptop Weight', 'Price': 'Laptop Price'})
fig.show()

# Scatter Plot: Price vs. Inches
fig = px.scatter(df, x='Inches', y='Price', title='Scatter Plot: Inches vs. Price', labels={'Inches': 'Screen Size (Inches)', 'Price': 'Laptop Price'})
fig.show()
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ef6b2fa3-8cb6-4106-819b-01fbcf8a7f54" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ef6b2fa3-8cb6-4106-819b-01fbcf8a7f54")) {                    Plotly.newPlot(                        "ef6b2fa3-8cb6-4106-819b-01fbcf8a7f54",                        [{"alignmentgroup":"True","hovertemplate":"Company=%{x}\u003cbr\u003eNumber of Laptops=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","pattern":{"shape":""}},"name":"","offsetgroup":"","orientation":"v","showlegend":false,"textposition":"auto","x":["MSI","Microsoft","Apple","lenevo","Asus","Chuwi","Acer","Dell","hp"],"xaxis":"x","y":[128,118,113,113,112,109,107,101,99],"yaxis":"y","type":"bar"}],                        {"template":{"data":{"histogram2dcontour":[{"type":"histogram2dcontour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"choropleth":[{"type":"choropleth","colorbar":{"outlinewidth":0,"ticks":""}}],"histogram2d":[{"type":"histogram2d","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmap":[{"type":"heatmap","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"heatmapgl":[{"type":"heatmapgl","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"contourcarpet":[{"type":"contourcarpet","colorbar":{"outlinewidth":0,"ticks":""}}],"contour":[{"type":"contour","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"surface":[{"type":"surface","colorbar":{"outlinewidth":0,"ticks":""},"colorscale":[[0.0,"#0d0887"],[0.1111111111111111,"#46039f"],[0.2222222222222222,"#7201a8"],[0.3333333333333333,"#9c179e"],[0.4444444444444444,"#bd3786"],[0.5555555555555556,"#d8576b"],[0.6666666666666666,"#ed7953"],[0.7777777777777778,"#fb9f3a"],[0.8888888888888888,"#fdca26"],[1.0,"#f0f921"]]}],"mesh3d":[{"type":"mesh3d","colorbar":{"outlinewidth":0,"ticks":""}}],"scatter":[{"fillpattern":{"fillmode":"overlay","size":10,"solidity":0.2},"type":"scatter"}],"parcoords":[{"type":"parcoords","line":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"scatterpolargl":[{"type":"scatterpolargl","marker":{"colorbar":{"outlinewidth":0,"ticks":""}}}],"bar":[{"error_x":{"color":"#2a3f5f"},"error_y":{"color":"#2a3f5f"},"marker":{"line":{"color":"#E5ECF6","width":0.5},"pattern":{"fillmode":"overlay","size":10,"solidity":0.2}},"type":"bar"}],"scattergeo":[{ ...
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="127677f4-ca95-46e3-80b9-3dc3cda47cdf" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("127677f4-ca95-46e3-80b9-3dc3cda47cdf")) {                    Plotly.newPlot(                        "127677f4-ca95-46e3-80b9-3dc3cda47cdf",                        [{"dimensions":[{"axis":{"matches":true},"label":"Inches","values":[17.040679937057998,16.54239484007617,17.29529433918756,11.526203243631654,12.649634256590849,15.543248856772662,15.559450833602275,17.806917376926048,12.846038951306689,15.204179606379835,13.91413107782111,11.60909891786426,15.481304786381182,12.140046588315377,16.18315761317629,12.919934728739609,11.14289640561816,13.98333935847321,11.759460670238749,17.350411831321335,16.07688606640552,11.040315806405005,16.4229390559853,12.062422664655324,16.096160942619065,12.03231658976971,17.61382848513086,14.050543264004954,12.776887275098286,13.426057858063889,17.282456930064377,11.023705442894355,17.107785879844293,17.509679259971982,11.227003211474088,17.264544074169837,15.324445048044865,13.38894261115102,11.897006090335006,12.27669312193173,11.482309042055382,14.708476335003388,16.68121458167773,11.260369444024624,16.01727690630932,14.976789811468183,16.701057052688974,17.644447474203286,14.633937172728016,13.39615683788456,17.618280432218715,12.995120114974238
14.976789811468183,16.701057052688974,17.644447474203286,14.633937172728016,13.39615683788456,17.618280432218715,12.995120114974238,13.291421472559374,11.423013920888751,13.573325706993227,13.123141735501248,13.248184175370213,13.220724159843334,11.17764234871078,13.440509239984529,12.265032162204704,17.19422593786943,13.964577149620382,14.86746090521603,12.229730614957818,11.71739663624422,16.315181070535914,15.362420681764192,14.618868841640428,15.131688162458277,13.949152146854477,15.467457205725127,15.58218234689596,12.384124008665852,14.757967887786466,17.781268124878135,16.77242854378187,12.609154978014978,14.101195446604208,12.44108259959516,11.814390650042473,14.084348754288856,13.706283324241095,12.759634544252984,13.150471182838947,15.8541834593068,15.532463404935037,13.064180998851413,12.58148974653752,15.512104956808075,12.085521061909509,17.862875747402533,12.929969648048877,17.532003191001355,13.868352374226935,16.280047493138973,12.004935262108276,12.884785673486524,13.96583954196632,16.49394432877368,15.38722027245822,11.991361127859742,17.558133738551128,17.439172177921385,15.59762844430995,14.028307845892195,16.126018477929073,13.136544091848736,14.497158426107,12.013361130380364,16.055912959084562,14.379441635628035,12.06875482215224,11.337592056015689,16.81358080440002,14.57589524806013,16.735305141954044,11.766044848623125,12.893758679354818,13.061923027967303,11.275876891131764,11.159789169320726,12.904417108579889,14.77294190142391,15.45905958347511,16.337487331692962,17.66642634971427,12.958700991386811,16.7032766707508,11.738169563135513,14.76227319859477,11.373640540744312,12.387877619513157,15.731542977930278,11.129186387647444,12.128571381048122,13.534041368039963,11.849660667459972,17.843166723894186,16.62096745164773,14.108826173626923,15.65373587184668,13.187401383681772,17.029436777363426,16.850319405149463,12.029502416875346,13.839458244364446,14.763764036796694,17.155836912266615,12.450568720763592,15.168339931155774,17.41886273210014,11.550774444094156,16.78958660965946,12.427064232453102,17.166830384719116,14.624561437503733,16.98621484406195,15.938860700520706,16.101608246965434,12.240773223961122,17.101265120323106,15.38481678325838,14.393643452722731,17.806869020937704,16.44487481275616,12.052126986083048,14.349223961161536,12.219115042045772,15.995390646773032,13.2534 ...

# %% [markdown]
# # Data Preprocessing

# %%
df_encoded = pd.get_dummies(df, columns=['TypeOfLaptop', 'Cpu', 'OpSys'], drop_first=True)

# %%
df_encoded['Ram'] = df_encoded['Ram'].astype(str).str.extract('(\d+)').astype(float, errors='ignore')

# Convert 'Memory' to numeric (assuming you want to extract the numeric part)
df_encoded['Memory'] = df_encoded['Memory'].astype(str).str.extract('(\d+)').astype(float)
# Assuming 'df_encoded' includes numerical features you want to normalize
numerical_features = ['Inches', 'Ram', 'Weight', 'Price']  # Update this list

# Create a StandardScaler object
scaler = StandardScaler()

# Fit and transform the numerical features
df_encoded[numerical_features] = scaler.fit_transform(df_encoded[numerical_features])

# %% [markdown]
# # Data Splitting

# %%
X = df_encoded.drop('Price', axis=1)  # Features
y = df_encoded['Price']  # Target variable

# One-hot encode categorical variables
X_encoded = pd.get_dummies(X, drop_first=True)
# Split the data into training and testing sets (80% train, 20% test)
X_train, X_test, y_train, y_test = train_test_split(X_encoded, y, test_size=0.2, random_state=42)

# Print the shapes of the resulting sets
print("Training set - Features:", X_train.shape, "Target:", y_train.shape)
print("Testing set - Features:", X_test.shape, "Target:", y_test.shape)
# Out:
# Training set - Features: (800, 37) Target: (800,)
# Testing set - Features: (200, 37) Target: (200,)

# %% [markdown]
# # Feature Selection

# %%
model = RandomForestRegressor(random_state=42)
model.fit(X_train, y_train)

# Calculate feature importances
feature_importance = pd.DataFrame({'Feature': X_train.columns, 'Importance': model.feature_importances_})
feature_importance = feature_importance.sort_values(by='Importance', ascending=False)
print(feature_importance)
print(feature_importance)
# Out:
#                                               Feature  Importance
# 1                                                 Ram    0.200572
# 0                                              Inches    0.149746
# 3                                              Weight    0.147025
# 2                                              Memory    0.053895
# 25                                   CompanyName_Dell    0.050299
# 28                                     CompanyName_hp    0.032920
# 21                                        OpSys_macOS    0.020785
# 22                                  CompanyName_Apple    0.016827
# 31                           ScreenResolution_Full HD    0.016081
# 36                        Gpu_NVIDIA GeForce GTX 1650    0.015773
# 30                                ScreenResolution_4K    0.015045
# 4                        TypeOfLaptop_Business Laptop    0.014632
# 35                         Gpu_Intel Iris Xe Graphics    0.013667
# 18                                        OpSys_No OS    0.013575
# 33  ScreenResolution_IPS Panel Full HD / Touchscre...    0.013511
# 5                                 TypeOfLaptop_Gaming    0.013464
# 8                            TypeOfLaptop_WorkStation    0.012840
# 17                           Cpu_Intel Xeon E3-1505M     0.012724
# 11                            Cpu_Intel Atom x5-Z8550    0.012408
# 9                                     Cpu_AMD Ryzen 5    0.012010
# 19                                   OpSys_Windows 10    0.011559
# 6                               TypeOfLaptop_NoteBook    0.011378
# 7                              TypeOfLaptop_UltraBook    0.011124
# 34  ScreenResolution_IPS Panel Retina Display 2560...    0.010720
# 32                     ScreenResolution_HD 1920x1080     0.010508
# 26                                    CompanyName_MSI    0.010251
# 27                              CompanyName_Microsoft    0.010244
# 20                                   OpSys_Windows 11    0.009613
# 12                 Cpu_Intel Celeron Dual Core 3855U     0.009298
# 13                                  Cpu_Intel Core i5    0.008924
# 24                                  CompanyName_Chuwi    0.008781
# 23                                   CompanyName_Asus    0.008703
# 10                                    Cpu_AMD Ryzen 7    0.008660
# 16                  Cpu_Intel Pentium Quad Core N4200    0.008499
# 15                                  Cpu_Intel Core i9    0.008077
# 14                                  Cpu_Intel Core i7    0.007965
# 29                                 CompanyName_lenevo    0.007893
#                                               Feature  Importance
# 1                                                 Ram    0.200572
# 0                                              Inches    0.149746
# 3                                              Weight    0.147025
# 2                                              Memory    0.053895
# 25                                   CompanyName_Dell    0.050299
# 28                                     CompanyName_hp    0.032920
# 21                                        OpSys_macOS    0.020785
# 22                                  CompanyName_Apple    0.016827
# 31                           ScreenResolution_Full HD    0.016081
# 36                        Gpu_NVIDIA GeForce GTX 1650    0.015773
# 30                                ScreenResolution_4K    0.015045
# 4                        TypeOfLaptop_Business Laptop    0.014632
# 35                         Gpu_Intel Iris Xe Graphics    0.013667
# 18                                        OpSys_No OS    0.013575
# 33  ScreenResolution_IPS Panel Full HD / Touchscre...    0.013511
# 5                                 TypeOfLaptop_Gaming    0.013464
# 8                            TypeOfLaptop_WorkStation    0.012840
# 17                           Cpu_Intel Xeon E3-1505M     0.012724
# 11                            Cpu_Intel Atom x5-Z8550    0.012408
# 9                                     Cpu_AMD Ryzen 5    0.012010
# 19                                   OpSys_Windows 10    0.011559
# 6                               TypeOfLaptop_NoteBook    0.011378
# 7                              TypeOfLaptop_UltraBook    0.011124
# 34  ScreenResolution_IPS Panel Retina Display 2560...    0.010720
# 32                     ScreenResolution_HD 1920x1080     0.010508
# 26                                    CompanyName_MSI    0.010251
# 27                              CompanyName_Microsoft    0.010244
# 20                                   OpSys_Windows 11    0.009613
# 12                 Cpu_Intel Celeron Dual Core 3855U     0.009298
# 13                                  Cpu_Intel Core i5    0.008924
# 24                                  CompanyName_Chuwi    0.008781
# 23                                   CompanyName_Asus    0.008703
# 10                                    Cpu_AMD Ryzen 7    0.008660
# 16                  Cpu_Intel Pentium Quad Core N4200    0.008499
# 15                                  Cpu_Intel Core i9    0.008077
# 14                                  Cpu_Intel Core i7    0.007965
# 29                                 CompanyName_lenevo    0.007893

# %% [markdown]
# # Correlation Analysis

# %%
numeric_columns = df_encoded.select_dtypes(include=['number'])

# Calculate the correlation matrix
correlation_matrix = numeric_columns.corr()

# Print the correlation matrix
print(correlation_matrix)
# Out:
#                                       Inches       Ram    Memory    Weight  \
# Inches                              1.000000 -0.014286 -0.072276  0.037982
# Ram                                -0.014286  1.000000  0.011465 -0.039935
# Memory                             -0.072276  0.011465  1.000000 -0.023323
# Weight                              0.037982 -0.039935 -0.023323  1.000000
# Price                              -0.012535  0.063615  0.060936 -0.024256
# TypeOfLaptop_Business Laptop        0.027049 -0.005201  0.001258 -0.029136
# TypeOfLaptop_Gaming                -0.029512  0.055038  0.005021 -0.002243
# TypeOfLaptop_NoteBook              -0.026505 -0.002650  0.009306 -0.008528
# TypeOfLaptop_UltraBook              0.067022 -0.032526 -0.024880  0.042165
# TypeOfLaptop_WorkStation           -0.027768  0.003103  0.020914  0.003021
# Cpu_AMD Ryzen 5                    -0.034611  0.017105  0.006697 -0.020274
# Cpu_AMD Ryzen 7                     0.024632  0.001566  0.018298  0.004803
# Cpu_Intel Atom x5-Z8550            -0.011936 -0.016526 -0.018882  0.021952
# Cpu_Intel Celeron Dual Core 3855U   0.017251  0.032237 -0.001551  0.022392
# Cpu_Intel Core i5                  -0.004718  0.021242 -0.025514  0.003640
# Cpu_Intel Core i7                   0.002574  0.007807  0.006083 -0.002063
# Cpu_Intel Core i9                   0.012414 -0.012311 -0.005229  0.010747
# Cpu_Intel Pentium Quad Core N4200  -0.054960 -0.047808  0.042371  0.042955
# Cpu_Intel Xeon E3-1505M             0.029676 -0.031893 -0.023755 -0.066262
# OpSys_No OS                        -0.024788 -0.042236  0.003839  0.016699
# OpSys_Windows 10                    0.045870  0.041523 -0.005356  0.047776
# OpSys_Windows 11                   -0.032318 -0.043306 -0.028922 -0.061299
# OpSys_macOS                         0.032233  0.072377  0.024393 -0.008173
#
#                                        Price  TypeOfLaptop_Business Laptop  \
# Inches                             -0.012535                      0.027049
# Ram                                 0.063615                     -0.005201
# Memory                              0.060936                      0.001258
# Weight                             -0.024256                     -0.029136
# Price                               1.000000                      0.039979
# TypeOfLaptop_Business Laptop        0.039979                      1.000000
# TypeOfLaptop_Gaming                 0.010832                     -0.207676
# TypeOfLaptop_NoteBook              -0.038953                     -0.196425
# TypeOfLaptop_UltraBook             -0.039869                     -0.206188
# TypeOfLaptop_WorkStation            0.001820                     -0.212855
# Cpu_AMD Ryzen 5                    -0.028909                      0.031098
# Cpu_AMD Ryzen 7                    -0.014104                      0.022099
# Cpu_Intel Atom x5-Z8550             0.039977                     -0.012840
# Cpu_Intel Celeron Dual Core 3855U   0.029745                     -0.055183
# Cpu_Intel Core i5                  -0.038007                      0.013020
# Cpu_Intel Core i7                   0.018757                      0.018755
# Cpu_Intel Core i9                  -0.006106                     -0.006448
# Cpu_Intel Pentium Quad Core N4200   0.006057                      0.019381
# Cpu_Intel Xeon E3-1505M            -0.002640                     -0.041841
# OpSys_No OS                        -0.054755                     -0.008969
# OpSys_Windows 10                    0.035297                      0.032247
# OpSys_Windows 11                   -0.018732                      0.034643
# OpSys_macOS                         0.037372                     -0.054249
#
#                                     TypeOfLaptop_Gaming  \
# Inches                                        -0.029512
# Ram                                            0.055038
# Memory                                         0.005021
# Weight                                        -0.002243
# Price                                          0.010832
# TypeOfLaptop_Business Laptop                  -0.207676
# TypeOfLaptop_Gaming                            1.000000
# TypeOfLaptop_NoteBook                         -0.190984
# TypeOfLaptop_UltraBook                        -0.200477
# TypeOfLaptop_WorkStation                      -0.206959
# Cpu_AMD Ryzen 5                               -0.025590
# Cpu_AMD Ryzen 7                               -0.007259
# Cpu_Intel Atom x5-Z8550                        0.011512
# Cpu_Intel Celeron Dual Core 3855U             -0.013171
# Cpu_Intel Core i5                             -0.005584
# Cpu_Intel Core i7                             -0.028401
# Cpu_Intel Core i9                             -0.027002
# Cpu_Intel Pentium Quad Core N4200              0.018037
# Cpu_Intel Xeon E3-1505M                        0.049218
# OpSys_No OS                                   -0.048963
# OpSys_Windows 10                               0.023052
# OpSys_Windows 11                              -0.011013
# OpSys_macOS                                    0.001345
#
#                                     TypeOfLaptop_NoteBook  \
# Inches                                          -0.026505
# Ram                                             -0.002650
# Memory                                           0.009306
# Weight                                          -0.008528
# Price                                           -0.038953
# TypeOfLaptop_Business Laptop                    -0.196425
# TypeOfLaptop_Gaming                             -0.190984
# TypeOfLaptop_NoteBook                            1.000000
# TypeOfLaptop_UltraBook                          -0.189616
# TypeOfLaptop_WorkStation                        -0.195747
# Cpu_AMD Ryzen 5                                 -0.003636
# Cpu_AMD Ryzen 7                                  0.005883
# Cpu_Intel Atom x5-Z8550                          0.000150
# Cpu_Intel Celeron Dual Core 3855U               -0.046660
# Cpu_Intel Core i5                                0.017534
# Cpu_Intel Core i7                               -0.006488
# Cpu_Intel Core i9                                0.042301
# Cpu_Intel Pentium Quad Core N4200               -0.013395
# Cpu_Intel Xeon E3-1505M                          0.013618
# OpSys_No OS                                      0.004851
# OpSys_Windows 10                                -0.018841
# OpSys_Windows 11                                 0.015114
# OpSys_macOS                                     -0.003405
#
#                                     TypeOfLaptop_UltraBook  \
# Inches                                            0.067022
# Ram                                              -0.032526
# Memory                                           -0.024880
# Weight                                            0.042165
# Price                                            -0.039869
# TypeOfLaptop_Business Laptop                     -0.206188
# TypeOfLaptop_Gaming                              -0.200477
# TypeOfLaptop_NoteBook                            -0.189616
# TypeOfLaptop_UltraBook                            1.000000
# TypeOfLaptop_WorkStation                         -0.205477
# Cpu_AMD Ryzen 5                                   0.012856
# Cpu_AMD Ryzen 7                                  -0.060819
# Cpu_Intel Atom x5-Z8550                          -0.020756
# Cpu_Intel Celeron Dual Core 3855U                 0.042775
# Cpu_Intel Core i5                                -0.047605
# Cpu_Intel Core i7                                -0.008539
# Cpu_Intel Core i9                                 0.038772
# Cpu_Intel Pentium Quad Core N4200                 0.002087
# Cpu_Intel Xeon E3-1505M                           0.034469
# OpSys_No OS                                      -0.001186
# OpSys_Windows 10                                 -0.021776
# OpSys_Windows 11                                  0.019648
# OpSys_macOS                                       0.023694
#
#                                     TypeOfLaptop_WorkStation  ...  \
# Inches                                             -0.027768  ...
# Ram                                                 0.003103  ...
# Memory                                              0.020914  ...
# Weight                                              0.003021  ...
# Price                                               0.001820  ...
# TypeOfLaptop_Business Laptop                       -0.212855  ...
# TypeOfLaptop_Gaming                                -0.206959  ...
# TypeOfLaptop_NoteBook                              -0.195747  ...
# TypeOfLaptop_UltraBook                             -0.205477  ...
# TypeOfLaptop_WorkStation                            1.000000  ...
# Cpu_AMD Ryzen 5                                    -0.013077  ...
# Cpu_AMD Ryzen 7                                     0.032015  ...
# Cpu_Intel Atom x5-Z8550                            -0.011939  ...
# Cpu_Intel Celeron Dual Core 3855U                   0.060636  ...
# Cpu_Intel Core i5                                   0.039706  ...
# Cpu_Intel Core i7                                  -0.007147  ...
# Cpu_Intel Core i9                                  -0.050488  ...
# Cpu_Intel Pentium Quad Core N4200                   0.020307  ...
# Cpu_Intel Xeon E3-1505M                            -0.040991  ...
# OpSys_No OS                                         0.036612  ...
# OpSys_Windows 10                                   -0.059567  ...
# OpSys_Windows 11                                   -0.053905  ...
# OpSys_macOS                                         0.029750  ...
#
#                                     Cpu_Intel Celeron Dual Core 3855U   \
# Inches                                                        0.017251
# Ram                                                           0.032237
# Memory                                                       -0.001551
# Weight                                                        0.022392
# Price                                                         0.029745
# TypeOfLaptop_Business Laptop                                 -0.055183
# TypeOfLaptop_Gaming                                          -0.013171
# TypeOfLaptop_NoteBook                                        -0.046660
# TypeOfLaptop_UltraBook                                        0.042775
# TypeOfLaptop_WorkStation                                      0.060636
# Cpu_AMD Ryzen 5                                              -0.106172
# Cpu_AMD Ryzen 7                                              -0.106172
# Cpu_Intel Atom x5-Z8550                                      -0.116472
# Cpu_Intel Celeron Dual Core 3855U                             1.000000
# Cpu_Intel Core i5                                            -0.112900
# Cpu_Intel Core i7                                            -0.107414
# Cpu_Intel Core i9                                            -0.106794
# Cpu_Intel Pentium Quad Core N4200                            -0.110482
# Cpu_Intel Xeon E3-1505M                                      -0.118235
# OpSys_No OS                                                   0.000387
# OpSys_Windows 10                                             -0.042631
# OpSys_Windows 11                                             -0.002190
# OpSys_macOS                                                   0.061304
#
#                                     Cpu_Intel Core i5  Cpu_Intel Core i7  \
# Inches                                      -0.004718           0.002574
# Ram                                          0.021242           0.007807
# Memory                                      -0.025514           0.006083
# Weight                                       0.003640          -0.002063
# Price                                       -0.038007           0.018757
# TypeOfLaptop_Business Laptop                 0.013020           0.018755
# TypeOfLaptop_Gaming                         -0.005584          -0.028401
# TypeOfLaptop_NoteBook                        0.017534          -0.006488
# TypeOfLaptop_UltraBook                      -0.047605          -0.008539
# TypeOfLaptop_WorkStation                     0.039706          -0.007147
# Cpu_AMD Ryzen 5                             -0.110327          -0.104967
# Cpu_AMD Ryzen 7                             -0.110327          -0.104967
# Cpu_Intel Atom x5-Z8550                     -0.121030          -0.115149
# Cpu_Intel Celeron Dual Core 3855U           -0.112900          -0.107414
# Cpu_Intel Core i5                            1.000000          -0.111618
# Cpu_Intel Core i7                           -0.111618           1.000000
# Cpu_Intel Core i9                           -0.110974          -0.105582
# Cpu_Intel Pentium Quad Core N4200           -0.114806          -0.109228
# Cpu_Intel Xeon E3-1505M                     -0.122862          -0.116893
# OpSys_No OS                                  0.050701          -0.012245
# OpSys_Windows 10                            -0.011302          -0.005357
# OpSys_Windows 11                            -0.012678          -0.007987
# OpSys_macOS                                 -0.007848          -0.008405
#
#                                     Cpu_Intel Core i9  \
# Inches                                       0.012414
# Ram                                         -0.012311
# Memory                                      -0.005229
# Weight                                       0.010747
# Price                                       -0.006106
# TypeOfLaptop_Business Laptop                -0.006448
# TypeOfLaptop_Gaming                         -0.027002
# TypeOfLaptop_NoteBook                        0.042301
# TypeOfLaptop_UltraBook                       0.038772
# TypeOfLaptop_WorkStation                    -0.050488
# Cpu_AMD Ryzen 5                             -0.104361
# Cpu_AMD Ryzen 7                             -0.104361
# Cpu_Intel Atom x5-Z8550                     -0.114485
# Cpu_Intel Celeron Dual Core 3855U           -0.106794
# Cpu_Intel Core i5                           -0.110974
# Cpu_Intel Core i7                           -0.105582
# Cpu_Intel Core i9                            1.000000
# Cpu_Intel Pentium Quad Core N4200           -0.108597
# Cpu_Intel Xeon E3-1505M                     -0.116218
# OpSys_No OS                                  0.022250
# OpSys_Windows 10                            -0.003709
# OpSys_Windows 11                             0.020419
# OpSys_macOS                                 -0.031378
#
#                                     Cpu_Intel Pentium Quad Core N4200  \
# Inches                                                      -0.054960
# Ram                                                         -0.047808
# Memory                                                       0.042371
# Weight                                                       0.042955
# Price                                                        0.006057
# TypeOfLaptop_Business Laptop                                 0.019381
# TypeOfLaptop_Gaming                                          0.018037
# TypeOfLaptop_NoteBook                                       -0.013395
# TypeOfLaptop_UltraBook                                       0.002087
# TypeOfLaptop_WorkStation                                     0.020307
# Cpu_AMD Ryzen 5                                             -0.107964
# Cpu_AMD Ryzen 7                                             -0.107964
# Cpu_Intel Atom x5-Z8550                                     -0.118438
# Cpu_Intel Celeron Dual Core 3855U                           -0.110482
# Cpu_Intel Core i5                                           -0.114806
# Cpu_Intel Core i7                                           -0.109228
# Cpu_Intel Core i9                                           -0.108597
# Cpu_Intel Pentium Quad Core N4200                            1.000000
# Cpu_Intel Xeon E3-1505M                                     -0.120231
# OpSys_No OS                                                 -0.012927
# OpSys_Windows 10                                             0.011800
# OpSys_Windows 11                                            -0.041620
# OpSys_macOS                                                 -0.000955
#
#                                     Cpu_Intel Xeon E3-1505M   OpSys_No OS  \
# Inches                                              0.029676    -0.024788
# Ram                                                -0.031893    -0.042236
# Memory                                             -0.023755     0.003839
# Weight                                             -0.066262     0.016699
# Price                                              -0.002640    -0.054755
# TypeOfLaptop_Business Laptop                       -0.041841    -0.008969
# TypeOfLaptop_Gaming                                 0.049218    -0.048963
# TypeOfLaptop_NoteBook                               0.013618     0.004851
# TypeOfLaptop_UltraBook                              0.034469    -0.001186
# TypeOfLaptop_WorkStation                           -0.040991     0.036612
# Cpu_AMD Ryzen 5                                    -0.115541     0.015978
# Cpu_AMD Ryzen 7                                    -0.115541    -0.016898
# Cpu_Intel Atom x5-Z8550                            -0.126749    -0.021868
# Cpu_Intel Celeron Dual Core 3855U                  -0.118235     0.000387
# Cpu_Intel Core i5                                  -0.122862     0.050701
# Cpu_Intel Core i7                                  -0.116893    -0.012245
# Cpu_Intel Core i9                                  -0.116218     0.022250
# Cpu_Intel Pentium Quad Core N4200                  -0.120231    -0.012927
# Cpu_Intel Xeon E3-1505M                             1.000000    -0.011592
# OpSys_No OS                                        -0.011592     1.000000
# OpSys_Windows 10                                    0.030906    -0.263589
# OpSys_Windows 11                                   -0.025316    -0.248305
# OpSys_macOS                                         0.007867    -0.284505
#
#                                     OpSys_Windows 10  OpSys_Windows 11  \
# Inches                                      0.045870         -0.032318
# Ram                                         0.041523         -0.043306
# Memory                                     -0.005356         -0.028922
# Weight                                      0.047776         -0.061299
# Price                                       0.035297         -0.018732
# TypeOfLaptop_Business Laptop                0.032247          0.034643
# TypeOfLaptop_Gaming                         0.023052         -0.011013
# TypeOfLaptop_NoteBook                      -0.018841          0.015114
# TypeOfLaptop_UltraBook                     -0.021776          0.019648
# TypeOfLaptop_WorkStation                   -0.059567         -0.053905
# Cpu_AMD Ryzen 5                             0.015286          0.004103
# Cpu_AMD Ryzen 7                            -0.010711          0.022099
# Cpu_Intel Atom x5-Z8550                     0.003752          0.012238
# Cpu_Intel Celeron Dual Core 3855U          -0.042631         -0.002190
# Cpu_Intel Core i5                          -0.011302         -0.012678
# Cpu_Intel Core i7                          -0.005357         -0.007987
# Cpu_Intel Core i9                          -0.003709          0.020419
# Cpu_Intel Pentium Quad Core N4200           0.011800         -0.041620
# Cpu_Intel Xeon E3-1505M                     0.030906         -0.025316
# OpSys_No OS                                -0.263589         -0.248305
# OpSys_Windows 10                            1.000000         -0.226739
# OpSys_Windows 11                           -0.226739          1.000000
# OpSys_macOS                                -0.259794         -0.244731
#
#                                     OpSys_macOS
# Inches                                 0.032233
# Ram                                    0.072377
# Memory                                 0.024393
# Weight                                -0.008173
# Price                                  0.037372
# TypeOfLaptop_Business Laptop          -0.054249
# TypeOfLaptop_Gaming                    0.001345
# TypeOfLaptop_NoteBook                 -0.003405
# TypeOfLaptop_UltraBook                 0.023694
# TypeOfLaptop_WorkStation               0.029750
# Cpu_AMD Ryzen 5                       -0.037998
# Cpu_AMD Ryzen 7                        0.028287
# Cpu_Intel Atom x5-Z8550                0.036108
# Cpu_Intel Celeron Dual Core 3855U      0.061304
# Cpu_Intel Core i5                     -0.007848
# Cpu_Intel Core i7                     -0.008405
# Cpu_Intel Core i9                     -0.031378
# Cpu_Intel Pentium Quad Core N4200     -0.000955
# Cpu_Intel Xeon E3-1505M                0.007867
# OpSys_No OS                           -0.284505
# OpSys_Windows 10                      -0.259794
# OpSys_Windows 11                      -0.244731
# OpSys_macOS                            1.000000
#
# [23 rows x 23 columns]

# %% [markdown]
# # RFE

# %%
model = LinearRegression()
rfe = RFE(model, n_features_to_select=1)
X_train_rfe = rfe.fit_transform(X_train, y_train)

# %%
pca = PCA(n_components=len(X_train.columns))
X_train_pca = pca.fit_transform(X_train)

# Get the explained variance ratio for each component
explained_variance_ratio = pca.explained_variance_ratio_
print(explained_variance_ratio)
# Out:
# [9.99805886e-01 2.87024462e-05 2.68657359e-05 2.65425173e-05
#  9.19152264e-06 6.11876572e-06 5.87569613e-06 5.35830622e-06
#  5.19050646e-06 5.10303374e-06 4.95805716e-06 4.82772375e-06
#  4.65495304e-06 4.50089078e-06 4.38255418e-06 3.88824972e-06
#  3.60326582e-06 3.42062573e-06 3.31533068e-06 3.11931026e-06
#  3.05995729e-06 2.96846656e-06 2.92949680e-06 2.71063064e-06
#  2.67087335e-06 2.64987292e-06 2.60060774e-06 2.56871050e-06
#  2.45975854e-06 2.38536868e-06 2.27378511e-06 2.15097757e-06
#  1.04911337e-06 7.54533206e-07 7.04973491e-07 3.06307204e-07
#  2.51164304e-07]

# %% [markdown]
# # Model Selection

# %%
models = [
    LinearRegression(),
    DecisionTreeRegressor(random_state=42),
    RandomForestRegressor(random_state=42),
    GradientBoostingRegressor(random_state=42),
    SVR()
]

# Evaluate models using cross-validation
for model in models:
    scores = cross_val_score(model, X_train, y_train, scoring='neg_mean_squared_error', cv=5)
    print(f"{model.__class__.__name__}: Mean MSE: {np.mean(-scores)}")

# Train and evaluate the best-performing model on the test set
best_model = RandomForestRegressor(random_state=42)
best_model.fit(X_train, y_train)
test_predictions = best_model.predict(X_test)
test_mse = mean_squared_error(y_test, test_predictions)
print(f"Test MSE for the best model: {test_mse}")
# Out:
# LinearRegression: Mean MSE: 0.9731589953901431
# DecisionTreeRegressor: Mean MSE: 1.466912942031452
# RandomForestRegressor: Mean MSE: 0.8117912334385557
# GradientBoostingRegressor: Mean MSE: 0.8699491081893086
# SVR: Mean MSE: 1.0010309461884157
# Test MSE for the best model: 0.8883650246543651

# %% [markdown]
# # Model Training

# %%
best_model = RandomForestRegressor(random_state=42)

# Train the model using the entire training dataset
best_model.fit(X_train, y_train)

# Make predictions on the test set
test_predictions = best_model.predict(X_test)

.5459126454355697,-0.6638409645605684,0.3573095212084068,-1.531133537078544,0.050698661837438375,-0.7230554665674513,-0.3084752869216963,-0.7602302081830319,0.6770681933268666,-0.8225412853195191,1.0351851264125265,2.964830767673623,0.7882730201005439,0.5418961722845868,-1.5137386824740349,1.0987149493752129,-0.1013419225467148,0.7590163250901023,0.33954587638548384,-0.9846419048743003,-0.9443875770286141,1.1168144033631302,-0.6632866278110775,0.39921669857144876,-0.7896253069475733,-0.6495575946771921,-1.4060859891894348,2.600482632570503,-0.8092149322245976,1.1502544123837926,-0.25394363003705234,0.6370148070944731,-1.3612143625023172,0.9938625318279382,1.201196848818423,1.0854015165533235,1.0316548030696144,-0.8556224625192208,1.0227915484770225,-0.2112938034890881,0 ...

# %%
test_predictions = best_model.predict(X_test)

# Evaluate performance metrics
mae = mean_absolute_error(y_test, test_predictions)
mse = mean_squared_error(y_test, test_predictions)
r_squared = r2_score(y_test, test_predictions)

# Create a DataFrame for visualization
evaluation_df = pd.DataFrame({'Actual': y_test, 'Predicted': test_predictions})

# Scatter plot
fig = px.scatter(evaluation_df, x='Actual', y='Predicted', title='Actual vs Predicted Prices')
fig.update_layout(xaxis_title='Actual Prices', yaxis_title='Predicted Prices')
fig.show()

# Print evaluation metrics
print(f"Mean Absolute Error (MAE): {mae}")
print(f"Mean Squared Error (MSE): {mse}")
print(f"R-squared (R2): {r_squared}")
# Out:
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="58c0489c-ff6e-4bf7-baf3-a084915f3db4" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("58c0489c-ff6e-4bf7-baf3-a084915f3db4")) {                    Plotly.newPlot(                        "58c0489c-ff6e-4bf7-baf3-a084915f3db4",                        [{"hovertemplate":"Actual=%{x}\u003cbr\u003ePredicted=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":[0.06526419923233473,0.2062217220616007,-1.2365787769435375,-1.032915669983169,0.45770470900862004,-1.0204055694136613,-1.1247613930515223,1.1271172546538373,1.3040418812432615,-1.457189751526599,-0.13082257315243442,1.1765153678916065,1.2162085639970133,-0.17552653354657424,-1.4160797040487094,0.5152916410744567,-1.1983316371580846,3.31902083092946,0.1741700717592131,0.907016344423828,-0.30991745007159477,-0.4446751692534827,1.29459389523118,-0.16404825871846523,-1.2954746745165064,-1.0387875438564815,-0.11181030604792931,-0.3309045374563262,-0.8439084954240658,-0.6948949692654164,-0.5444142842362004,0.11633141171959376,-0.9877961026663526,0.9247479401065406,-0.2252627910527924,-1.0959908787998225,3.3493990887935063,-0.3930437802663877,-1.330682461945254,-0.8811689107599671,0.6235379632164225,0.8501720121532472,-0.07248772350972028,-0.9203193208779954,0.7985376440670194,0.3204940887937631,0.20535487809673317,0.7212961078598533,-1.0655050619120945,-0.4072201447342517,1.0136481931859314,1.027382194013716,-0.3363161257928593,-0.08938333377419055,2.11628608645206,0.1548396580411964,-0.9283577806468591,-0.49395605808266574,2.3398336523946335,-0.7933475794556872,-1.4297520341283831,0.5746486899274138,0.20324546229514084,-0.6829438765445205,-1.4934863918289583,1.011372171610695,-0.8148898797721787,-1.3608227735023597,0.7924746420170077,-1.217469782561069,-0.02888017746508159,0.9673417690953016,2.693664428333695,-1.388272596284586,0.7820463414179543,-1.2921269978006948,0.5801225074949695,-0.463116381288628,0.35979363405743875,-0.25454543240558825,-0.18919747904155718,-0.7194044341129806,-0.41255606993928967,0.591521737872639,-1.3556841724245476,1.3019767143644896,0.5309028312370786,-1.0246936100135806,0.25152530797923217,1.2765142163129826,4.605351892284034,-0.8393680470587109,0.8033835085211896,-1.471864873637185,0.9029607453278996,-1.1677768952658698,-1.1203085492131037,-0.3113270231526405,-1.5045065470168153,-1.3397434403054762,0.9351133905097312,-1.1920516642670482,-0.32862537969646793,0.342689379807485,0.573294877798976,0.2991391749740169,1.0281475818114563,0.468442129187578,1.2876203363116738,-0.43175407107706654,0.08348361565473088,0.1722866604087826,0.8822754840624786,1.1938780639325042,0.6780817598272626,1.331846211169565,-0.46163861384754495,0.5946836760758675,1.0301969514750025,0.6648145238098817,0.062405478361973965,-0.4004866361040651,-0.6304098541036837,-0.44943796469223873,0.5459126454355697,-0.6638409645605684,0.3573095212084068,-1.531133537078544,0.050698661837438375,-0.7230554665674513,-0.3084752869216963,-0.7602302081830319,0.6770681933268666,-0.8225412853195191,1.0351851264125265,2.964830767673623,0.7882730201005439,0.5418961722845868,-1.5137386824740349,1.0987149493752129,-0.1013419225467148,0.7590163250901023,0.33954587638548384,-0.9846419048743003,-0.9443875770286141,1.1168144033631302,-0.6632866278110775,0.39921669857144876,-0.7896253069475733,-0.6495575946771921,-1.4060859891894348,2.600482632570503,-0.8092149322245976,1.1502544123837926,-0.25394363003705234,0.6370148070944731,-1.3612143625023172,0.9938625318279382,1.201196848818423,1.0854015165533235,1.0316548030696144,-0.8556224625192208,1.0227915484770225,-0.2112938034890881,0 ...
# Mean Absolute Error (MAE): 0.7793732985875605
# Mean Squared Error (MSE): 0.8883650246543651
# R-squared (R2): 0.17054512585754167

# %%
param_grid = {
    'n_estimators': [50, 100, 200],
    'max_depth': [None, 10, 20],
    'min_samples_split': [2, 5, 10],
    'min_samples_leaf': [1, 2, 4]
}

# Instantiate the Random Forest Regressor
base_model = RandomForestRegressor(random_state=42)

# Create the GridSearchCV object
grid_search = GridSearchCV(base_model, param_grid, cv=5, scoring='neg_mean_squared_error', n_jobs=-1)

# Perform the grid search on the training data
grid_search.fit(X_train, y_train)

# Get the best hyperparameters from the grid search
best_params = grid_search.best_params_
print("Best Hyperparameters:", best_params)

# Train the model with the best hyperparameters on the entire training set
best_model = grid_search.best_estimator_

# Make predictions on the test set
test_predictions = best_model.predict(X_test)

# Visualize actual vs. predicted prices
evaluation_df = pd.DataFrame({'Actual': y_test, 'Predicted': test_predictions})
fig = px.scatter(evaluation_df, x='Actual', y='Predicted', title='Actual vs Predicted Prices (Tuned Model)')
fig.update_layout(xaxis_title='Actual Prices', yaxis_title='Predicted Prices')
fig.show()
# Out:
# Best Hyperparameters: {'max_depth': 10, 'min_samples_leaf': 4, 'min_samples_split': 10, 'n_estimators': 200}
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax && window.MathJax.Hub && window.MathJax.Hub.Config) {window.MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
#         <script charset="utf-8" src="https://cdn.plot.ly/plotly-2.24.1.min.js"></script>                <div id="ae6ecdfa-a5ae-484a-92a2-13e550f1d1e7" class="plotly-graph-div" style="height:525px; width:100%;"></div>            <script type="text/javascript">                                    window.PLOTLYENV=window.PLOTLYENV || {};                                    if (document.getElementById("ae6ecdfa-a5ae-484a-92a2-13e550f1d1e7")) {                    Plotly.newPlot(                        "ae6ecdfa-a5ae-484a-92a2-13e550f1d1e7",                        [{"hovertemplate":"Actual=%{x}\u003cbr\u003ePredicted=%{y}\u003cextra\u003e\u003c\u002fextra\u003e","legendgroup":"","marker":{"color":"#636efa","symbol":"circle"},"mode":"markers","name":"","orientation":"v","showlegend":false,"x":